# %% [markdown]
# # Agriculture and Rular Development Trends in Nepal
# - Agricultural irrigated land (% of total agricultural land)
# - Agricultural land (% of land area)
# - Agricultural land (sq. km)
# - Agricultural machinery, tractors
# - Agricultural machinery, tractors per 100 sq. km of arable land
# - Agricultural methane emissions (% of total)
# - Agricultural methane emissions (thousand metric tons of CO2 equivalent)
# - Agricultural nitrous oxide emissions (% of total)
# - Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# - Agricultural raw materials exports (% of merchandise exports)
# - Agricultural raw materials imports (% of merchandise imports)
# - Agriculture, forestry, and fishing, value added (% of GDP)
# - Agriculture, forestry, and fishing, value added (current US$)
# - Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)
# - Arable land (% of land area)
# - Arable land (hectares per person)
# - Arable land (hectares)
# - Average precipitation in depth (mm per year)
# - Cereal production (metric tons)
# - Cereal yield (kg per hectare)
# - Crop production index (2014-2016 = 100)
# - Employment in agriculture (% of total employment) (modeled ILO estimate)
# - Employment in agriculture, female (% of female employment) (modeled ILO estimate)
# - Employment in agriculture, male (% of male employment) (modeled ILO estimate)
# - Fertilizer consumption (% of fertilizer production)
# - Fertilizer consumption (kilograms per hectare of arable land)
# - Food production index (2014-2016 = 100)
# - Forest area (% of land area)
# - Forest area (sq. km)
# - Land area (sq. km)
# - Land under cereal production (hectares)
# - Livestock production index (2014-2016 = 100)
# - Permanent cropland (% of land area)
# - Access to electricity, rural (% of rural population)
# - Rural land area (sq. km)
# - Rural land area where elevation is below 5 meters (% of total land area)
# - Rural land area where elevation is below 5 meters (sq. km)
# - Rural population
# - Rural population (% of total population)
# - Rural population growth (annual %)
# - Rural population living in areas where elevation is below 5 meters (% of total population)
# - Surface area (sq. km)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/kaggle/input/nepal-development-indicator-trends-1960-2023/Nepal_Development_Indicator_Trends.csv')
df.head()
# Out:
#   Country Name Country Code  \
# 0        Nepal          NPL
# 1        Nepal          NPL
# 2        Nepal          NPL
# 3        Nepal          NPL
# 4        Nepal          NPL
#
#                                       Indicator Name    Indicator Code  1960  \
# 0         Intentional homicides (per 100,000 people)    VC.IHR.PSRC.P5   NaN
# 1  Internally displaced persons, new displacement...       VC.IDP.NWDS   NaN
# 2  Voice and Accountability: Percentile Rank, Upp...  VA.PER.RNK.UPPER   NaN
# 3                 Voice and Accountability: Estimate            VA.EST   NaN
# 4              High-technology exports (current US$)    TX.VAL.TECH.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2014          2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  2.031891e+00  2.020983e+00
# 1   NaN   NaN   NaN   NaN   NaN  ...  7.400000e+04  2.623000e+06
# 2   NaN   NaN   NaN   NaN   NaN  ...  3.940887e+01  4.039409e+01
# ...

# %%
#Function to extract row informations
def extract_row_info(df, row_index):
    # Extract the specified row of data
    row_data = df.iloc[row_index]

    # Extract the title (Series Name)
    title = row_data['Indicator Name']

    # Extract the data
    data = {col: row_data[col] for col in row_data.index[4:] if row_data[col] not in ('..', 'NaN', '')}

    # Convert numeric values to integers
    data = {col: float(value) if pd.notnull(value) and value not in ('..', 'NaN', '') else None for col, value in data.items()}

    # Extract years and values from the data dictionary
    years = []
    values = []
    for col, value in data.items():
        try:
            year = int(col.split(' ')[0])
            years.append(year)
            values.append(value)
        except ValueError:
            pass

    return title, data, years, values

# %%
#Function to draw plot
def plot_data(years, values, title):
      plt.figure(figsize=(8, 4))
      plt.plot(years, values, marker='o', linestyle='-', color='b')

      plt.title(f'{title} in Nepal')
      plt.xlabel('Year')
      plt.ylabel('Values')
      plt.xticks(rotation=45)
      plt.grid(True)
      plt.tight_layout()
      #plt.savefig(f'{output_folder}/{title}.png')
      plt.show()

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 388)

# Remove None values from the list
filtered_values = [x for x in values if x is not None]

# Calculate the average of the remaining values
average = np.mean(filtered_values)

print(f'Average Agricultural irrigated land (% of total agricultural land) in Nepal is : {average}%')
# Out:
# Average Agricultural irrigated land (% of total agricultural land) in Nepal is : 26.412386806%

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 850)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1119)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 851)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1472)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1436)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1310)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 357)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1084)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 194)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 17)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 623)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 466)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1074)
# Remove None values from the list
filtered_values = [x for x in values if x is not None]

# Calculate the average of the remaining values
average = np.mean(filtered_values)

print(f'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal) in Nepal is : {average}%')
# Out:
# Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal) in Nepal is : 98.03916362809522%

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1118)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1476)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 391)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1473)
# Remove None values from the list
filtered_values = [x for x in values if x is not None]

# Calculate the average of the remaining values
average = np.mean(filtered_values)

print(f'Average precipitation in depth (mm per year) in Nepal is : {average} mm')
# Out:
# Average precipitation in depth (mm per year) in Nepal is : 1500.0 mm

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1114)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 656)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 657)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1242)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 559)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 754)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1477)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 386)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 847)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1116)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 849)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1471)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 390)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 28)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 440)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 212)
plot_data(years, values, title)

# %%
# Extract information for the current row index
title, data, years, values = extract_row_info(df, 1113)

# Remove None values from the list
filtered_values = [x for x in values if x is not None]

# Calculate the average of the remaining values
average = np.mean(filtered_values)

print(f'Average Surface area (sq. km) in Nepal is : {average}')
# Out:
# Average Surface area (sq. km) in Nepal is : 147180.0
